# %%
# !pip install torch torchvision torchaudio
# !pip install transformers
# !pip install scikit-learn numpy tqdm
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.6 MB 2.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/1.6 MB 2.1 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.6 MB 2.1 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.6 MB 2.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.6 MB 2.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.6 MB 2.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.7/1.6 MB 2.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.6 MB 2.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.1/1.6 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 2.4 MB/s eta 0:00:01
# ...

# %%
# !pip uninstall torch -y
# !pip cache purge
# Out:
# Found existing installation: torch 2.6.0
# Uninstalling torch-2.6.0:
#   Successfully uninstalled torch-2.6.0
# Files removed: 42

# %%
# !pip install torch torchvision torchaudio
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/204.1 MB 1.7 MB/s eta 0:01:58
#    ---------------------------------------- 0.2/204.1 MB 1.8 MB/s eta 0:01:56
#    ---------------------------------------- 0.3/204.1 MB 1.9 MB/s eta 0:01:48
#    ---------------------------------------- 0.4/204.1 MB 1.9 MB/s eta 0:01:47
#    ---------------------------------------- 0.5/204.1 MB 1.9 MB/s eta 0:01:49
#    ---------------------------------------- 0.6/204.1 MB 2.0 MB/s eta 0:01:40
#    ---------------------------------------- 0.7/204.1 MB 2.1 MB/s eta 0:01:36
#    ---------------------------------------- 0.8/204.1 MB 2.2 MB/s eta 0:01:34
#    ---------------------------------------- 1.0/204.1 MB 2.3 MB/s eta 0:01:31
#    ---------------------------------------- 1.1/204.1 MB 2.3 MB/s eta 0:01:28
# ...

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
import torch
print(torch.__version__)  # Should print the PyTorch version
print(torch.cuda.is_available())  # Should print True if CUDA is available
# Out:
# 2.6.0+cpu
# False

# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForQuestionAnswering
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# %%
# Initialize the Question Answering pipeline using Hugging Face's transformers
qa_pl = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
# Sample context: You can replace this with the content of a book or any text
context = """
The term “Data Science” was created in the early 1960s to describe a new profession that would support the understanding and interpretation of the large amounts of data which was being amassed at the time. 
(At the time, there was no way of predicting the truly massive amounts of data over the next fifty years.)
Data Science continues to evolve as a discipline using computer science and statistical methodology to make useful predictions and gain insights in a wide range of fields.
While Data Science is used in areas such as astronomy and medicine, it is also used in business to help make smarter decisions.
"""

# %%
# Example questions
que_1 = "Which year Data science was created?"
que_2 = "in which areas it is used?"

# %%
# Answer the questions using the QA pipeline
ans_1 = qa_pl(question=que_1, context=context)
ans_2 = qa_pl(question=que_2, context=context)

# %%
# Print the answers
print(f"Answer for Question 1: {ans_1['answer']}")
print(f"Answer for Question 2: {ans_2['answer']}")
# Out:
# Answer for Question 1: 1960s
# Answer for Question 2: astronomy and medicine

# %%
accuracy_score(qa_pl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 accuracy_score(qa_pl)
#
# NameError: name 'accuracy_score' is not defined
